# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('wineset.csv',header=None)
df.head(3)
# Out:
#      0        1           2     3     4    5        6           7   \
# 0  Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids
# 1     1    14.23        1.71  2.43  15.6  127      2.8        3.06
# 2     1     13.2        1.78  2.14  11.2  100     2.65        2.76
#
#                      8        9          10    11    12       13
# 0  Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 1                   .28     2.29       5.64  1.04  3.92     1065
# 2                   .26     1.28       4.38  1.05   3.4     1050

# %%
df.drop(df.index[0])
# Out:
#     name alcohol malicAcid   ash ashalcalinity magnesium totalPhenols  \
# 1      1   14.23      1.71  2.43          15.6       127          2.8
# 2      1    13.2      1.78  2.14          11.2       100         2.65
# 3      1   13.16      2.36  2.67          18.6       101          2.8
# 4      1   14.37      1.95   2.5          16.8       113         3.85
# 5      1   13.24      2.59  2.87            21       118          2.8
# ..   ...     ...       ...   ...           ...       ...          ...
# 174    3   13.71      5.65  2.45          20.5        95         1.68
# 175    3    13.4      3.91  2.48            23       102          1.8
# 176    3   13.27      4.28  2.26            20       120         1.59
# 177    3   13.17      2.59  2.37            20       120         1.65
# 178    3   14.13       4.1  2.74          24.5        96         2.05
#
#     flavanoids nonFlavanoidPhenols proanthocyanins colorIntensity   hue  \
# 1         3.06                 .28            2.29           5.64  1.04
# 2         2.76                 .26            1.28           4.38  1.05
# 3         3.24                  .3            2.81           5.68  1.03
# 4         3.49                 .24            2.18            7.8   .86
# 5         2.69                 .39            1.82           4.32  1.04
# ..         ...                 ...             ...            ...   ...
# 174        .61                 .52            1.06            7.7   .64
# 175        .75                 .43            1.41            7.3    .7
# 176        .69                 .43            1.35           10.2   .59
# 177        .68                 .53            1.46            9.3    .6
# 178        .76                 .56            1.35            9.2   .61
#
#     od280_od315 proline
# 1          3.92    1065
# 2           3.4    1050
# 3          3.17    1185
# 4          3.45    1480
# 5          2.93     735
# ..          ...     ...
# 174        1.74     740
# 175        1.56     750
# 176        1.56     835
# 177        1.62     840
# 178         1.6     560
#
# [178 rows x 14 columns]

# %%
df.columns = [  'name'
                 ,'alcohol'
             	,'malicAcid'
             	,'ash'
            	,'ashalcalinity'
             	,'magnesium'
            	,'totalPhenols'
             	,'flavanoids'
             	,'nonFlavanoidPhenols'
             	,'proanthocyanins'
            	,'colorIntensity'
             	,'hue'
             	,'od280_od315'
             	,'proline'
                ]

df.head(3)
# Out:
#    name  alcohol   malicAcid   ash ashalcalinity magnesium totalPhenols  \
# 0  Wine  Alcohol  Malic.acid   Ash           Acl        Mg      Phenols
# 1     1    14.23        1.71  2.43          15.6       127          2.8
# 2     1     13.2        1.78  2.14          11.2       100         2.65
#
#    flavanoids   nonFlavanoidPhenols proanthocyanins colorIntensity   hue  \
# 0  Flavanoids  Nonflavanoid.phenols         Proanth      Color.int   Hue
# 1        3.06                   .28            2.29           5.64  1.04
# 2        2.76                   .26            1.28           4.38  1.05
#
#   od280_od315  proline
# 0          OD  Proline
# 1        3.92     1065
# 2         3.4     1050

# %%
df.isnull().sum()
# Out:
# name                   0
# alcohol                0
# malicAcid              0
# ash                    0
# ashalcalinity          0
# magnesium              0
# totalPhenols           0
# flavanoids             0
# nonFlavanoidPhenols    0
# proanthocyanins        0
# colorIntensity         0
# hue                    0
# od280_od315            0
# proline                0
# dtype: int64

# %%
df.drop(df.index[0])
# Out:
#     name alcohol malicAcid   ash ashalcalinity magnesium totalPhenols  \
# 1      1   14.23      1.71  2.43          15.6       127          2.8
# 2      1    13.2      1.78  2.14          11.2       100         2.65
# 3      1   13.16      2.36  2.67          18.6       101          2.8
# 4      1   14.37      1.95   2.5          16.8       113         3.85
# 5      1   13.24      2.59  2.87            21       118          2.8
# ..   ...     ...       ...   ...           ...       ...          ...
# 174    3   13.71      5.65  2.45          20.5        95         1.68
# 175    3    13.4      3.91  2.48            23       102          1.8
# 176    3   13.27      4.28  2.26            20       120         1.59
# 177    3   13.17      2.59  2.37            20       120         1.65
# 178    3   14.13       4.1  2.74          24.5        96         2.05
#
#     flavanoids nonFlavanoidPhenols proanthocyanins colorIntensity   hue  \
# 1         3.06                 .28            2.29           5.64  1.04
# 2         2.76                 .26            1.28           4.38  1.05
# 3         3.24                  .3            2.81           5.68  1.03
# 4         3.49                 .24            2.18            7.8   .86
# 5         2.69                 .39            1.82           4.32  1.04
# ..         ...                 ...             ...            ...   ...
# 174        .61                 .52            1.06            7.7   .64
# 175        .75                 .43            1.41            7.3    .7
# 176        .69                 .43            1.35           10.2   .59
# 177        .68                 .53            1.46            9.3    .6
# 178        .76                 .56            1.35            9.2   .61
#
#     od280_od315 proline
# 1          3.92    1065
# 2           3.4    1050
# 3          3.17    1185
# 4          3.45    1480
# 5          2.93     735
# ..          ...     ...
# 174        1.74     740
# 175        1.56     750
# 176        1.56     835
# 177        1.62     840
# 178         1.6     560
#
# [178 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# name                   0
# alcohol                0
# malicAcid              0
# ash                    0
# ashalcalinity          0
# magnesium              0
# totalPhenols           0
# flavanoids             0
# nonFlavanoidPhenols    0
# proanthocyanins        0
# colorIntensity         0
# hue                    0
# od280_od315            0
# proline                0
# dtype: int64

# %%
import seaborn as sns

sns.heatmap(df.isnull(), annot=True)
plt.show()

# %%
X= df.drop(['name','ash'], axis=1)

X.head()
# Out:
#    alcohol   malicAcid ashalcalinity magnesium totalPhenols  flavanoids  \
# 0  Alcohol  Malic.acid           Acl        Mg      Phenols  Flavanoids
# 1    14.23        1.71          15.6       127          2.8        3.06
# 2     13.2        1.78          11.2       100         2.65        2.76
# 3    13.16        2.36          18.6       101          2.8        3.24
# 4    14.37        1.95          16.8       113         3.85        3.49
#
#     nonFlavanoidPhenols proanthocyanins colorIntensity   hue od280_od315  \
# 0  Nonflavanoid.phenols         Proanth      Color.int   Hue          OD
# 1                   .28            2.29           5.64  1.04        3.92
# 2                   .26            1.28           4.38  1.05         3.4
# 3                    .3            2.81           5.68  1.03        3.17
# 4                   .24            2.18            7.8   .86        3.45
#
#    proline
# 0  Proline
# 1     1065
# 2     1050
# 3     1185
# 4     1480

# %%
df.drop(df.index[0])
# Out:
#     name alcohol malicAcid   ash ashalcalinity magnesium totalPhenols  \
# 1      1   14.23      1.71  2.43          15.6       127          2.8
# 2      1    13.2      1.78  2.14          11.2       100         2.65
# 3      1   13.16      2.36  2.67          18.6       101          2.8
# 4      1   14.37      1.95   2.5          16.8       113         3.85
# 5      1   13.24      2.59  2.87            21       118          2.8
# ..   ...     ...       ...   ...           ...       ...          ...
# 174    3   13.71      5.65  2.45          20.5        95         1.68
# 175    3    13.4      3.91  2.48            23       102          1.8
# 176    3   13.27      4.28  2.26            20       120         1.59
# 177    3   13.17      2.59  2.37            20       120         1.65
# 178    3   14.13       4.1  2.74          24.5        96         2.05
#
#     flavanoids nonFlavanoidPhenols proanthocyanins colorIntensity   hue  \
# 1         3.06                 .28            2.29           5.64  1.04
# 2         2.76                 .26            1.28           4.38  1.05
# 3         3.24                  .3            2.81           5.68  1.03
# 4         3.49                 .24            2.18            7.8   .86
# 5         2.69                 .39            1.82           4.32  1.04
# ..         ...                 ...             ...            ...   ...
# 174        .61                 .52            1.06            7.7   .64
# 175        .75                 .43            1.41            7.3    .7
# 176        .69                 .43            1.35           10.2   .59
# 177        .68                 .53            1.46            9.3    .6
# 178        .76                 .56            1.35            9.2   .61
#
#     od280_od315 proline
# 1          3.92    1065
# 2           3.4    1050
# 3          3.17    1185
# 4          3.45    1480
# 5          2.93     735
# ..          ...     ...
# 174        1.74     740
# 175        1.56     750
# 176        1.56     835
# 177        1.62     840
# 178         1.6     560
#
# [178 rows x 14 columns]

# %%
Y=df.iloc[:,:1]
Y.head(2)
# Out:
#    name
# 0  Wine
# 1     1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

print(X_train.shape)
print(X_test.shape)
# Out:
# (125, 12)
# (54, 12)

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier


models = []

models.append(("Logistic Regression:",LogisticRegression()))
models.append(("Decision Tree:",DecisionTreeClassifier()))


print('Models appended...')
# Out:
# Models appended...
